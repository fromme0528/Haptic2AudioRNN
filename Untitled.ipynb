# %% [markdown]
# TEST CODES

# %%
# %run ./solver.py ./dataset/input_accel ./dataset/audio_split ./output train ""
# Out:
# Namespace(inPath='./dataset/input_accel', inPath2='./dataset/audio_split', mode='train', modelPath='./output', prefix='')
# Dataset Load
# len of dataset :  331 331
# Train Start...
# -0.0002568817138671875 0.0007253036136244314 0.526153564453125 -0.677459716796875
# 0.8446413305545523 0.011211442699669682 0.9690194263115722 0.46305558521472506
# Epoch [1/100], Iter [1/332], Loss: 0.8449
# --- 0.6833159923553467 seconds for epoch ---
# -0.00018384552001953126 0.0007003073779187215 0.593414306640625 -0.724151611328125
# -0.3005974770971462 0.06592116137432243 0.19725288059196483 -0.6735962062199674
# Epoch [1/100], Iter [21/332], Loss: 0.3112
# --- 15.89066219329834 seconds for epoch ---
# -0.00022095870971679688 0.0008383171866862171 0.584808349609375 -0.7491455078125
# -0.3272130530281827 0.05562819218171171 0.20048166358462624 -0.620181299000598
# Epoch [1/100], Iter [41/332], Loss: 0.3300
# --- 31.037638664245605 seconds for epoch ---
# ...

# %%
# %run ./solver.py ./dataset/input_accel ./dataset/audio_split ./output train ""
# Out:
# Namespace(inPath='./dataset/input_accel', inPath2='./dataset/audio_split', mode='train', modelPath='./output', prefix='')
# Dataset Load
# ...
